# %%
# pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.9/608.9 kB 8.6 MB/s eta 0:00:00
# ...

# %%
# from ultralytics import YOLO

# %%
# model= YOLO('yolov8l.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
# ...

# %%
# model_300=model.train(data="/content/drive/MyDrive/Colab_Helmet/data.yaml",epochs=300)
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# model_300_test=YOLO('/content/drive/MyDrive/best_300.pt')

# %%
# !yolo detect predict model="/content/drive/MyDrive/best_300.pt" source="/content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (443/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (444/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 18.8ms
# video 1/1 (445/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 19.7ms
# video 1/1 (446/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 19.2ms
# video 1/1 (447/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 18.6ms
# video 1/1 (448/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 19.4ms
# video 1/1 (449/5440) /content/drive/MyDrive/MotoGP™ Indianapolis 2014 – Best slow motion.mp4: 384x640 (no detections), 19.3ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/MotoGP™ Indianapolis 2014 – Best slow motion.avi"} -vcodec libx264 {"test_out_1.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# from google.colab import files
# files.download("/content/runs/detect/predict/MotoGP™ Indianapolis 2014 – Best slow motion.avi")

# %%
# !yolo detect predict model="/content/drive/MyDrive/best_300.pt" source="/content/drive/MyDrive/R15 V4 Whatsapp Status New Bike R15 v4 Video _ Talking To The Moon x Rait Zara Si Song Status_#R15v4.mp4"
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# video 1/1 (1/472) /content/drive/MyDrive/R15 V4 Whatsapp Status New Bike R15 v4 Video _ Talking To The Moon x Rait Zara Si Song Status_#R15v4.mp4: 480x640 (no detections), 127.5ms
# video 1/1 (2/472) /content/drive/MyDrive/R15 V4 Whatsapp Status New Bike R15 v4 Video _ Talking To The Moon x Rait Zara Si Song Status_#R15v4.mp4: 480x640 (no detections), 42.0ms
# video 1/1 (3/472) /content/drive/MyDrive/R15 V4 Whatsapp Status New Bike R15 v4 Video _ Talking To The Moon x Rait Zara Si Song Status_#R15v4.mp4: 480x640 (no detections), 42.0ms
# video 1/1 (4/472) /content/drive/MyDrive/R15 V4 Whatsapp Status New Bike R15 v4 Video _ Talking To The Moon x Rait Zara Si Song Status_#R15v4.mp4: 480x640 (no detections), 41.9ms
# ...

# %%
# !yolo detect predict model="/content/drive/MyDrive/best_300.pt" source="/content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4"
# Out:
# Ultralytics YOLOv8.0.164 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# video 1/1 (1/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 108.7ms
# video 1/1 (2/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 38.4ms
# video 1/1 (3/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 38.1ms
# video 1/1 (4/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 32.9ms
# video 1/1 (5/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 32.8ms
# video 1/1 (6/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 32.8ms
# video 1/1 (7/4761) /content/drive/MyDrive/TESSIN RIDE WITH BOBBER GARAGE.mp4: 384x640 (no detections), 32.8ms
# ...

# %%
# !pip install youtube-dl

# %%
# from pytube import YouTube
# import os

# def downloadYouTube(videourl, path):

#     yt = YouTube(videourl)
#     yt = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
#     if not os.path.exists(path):
#         os.makedirs(path)
#     yt.download(path)

# downloadYouTube('https://www.youtube.com/watch?v=iJZcjZD0fw0&t=212s', '/content/drive/MyDrive/Colab_Helmet')

# %%
# !yolo detect predict model="/content/drive/MyDrive/best_300.pt" source="/content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (22005/27002) /content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4: 384x640 (no detections), 20.3ms
# video 1/1 (22006/27002) /content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4: 384x640 (no detections), 23.1ms
# video 1/1 (22007/27002) /content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4: 384x640 (no detections), 19.8ms
# video 1/1 (22008/27002) /content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4: 384x640 (no detections), 19.9ms
# video 1/1 (22009/27002) /content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4: 384x640 (no detections), 20.1ms
# video 1/1 (22010/27002) /content/drive/MyDrive/Colab_Helmet/15 minutes of heavy traffic noise in India  14-08-2022.mp4: 384x640 (no detections), 19.9ms
# ...
